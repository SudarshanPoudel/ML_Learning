# %%
#Importing pandas Libraray
import pandas as pd
import numpy as np

# %% [markdown]
# Creating a pandas data frame

# %%
#Importing california house price data
from sklearn.datasets import fetch_california_housing
california_dataset = fetch_california_housing()

# %%
type(california_dataset)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(california_dataset)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
#Pandas dataframe
california_df = pd.DataFrame(california_dataset.data, columns=california_dataset.feature_names)

# %%
#Print first 5 rows od data frame
california_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
#Shape of data frame
california_df.shape
# Out:
# (20640, 8)

# %% [markdown]
# Importing csv file in pandas

# %%
#csv file to pandas df
diabitage_df = pd.read_csv('DataSets/diabetes.csv')

# We can read excel file with function pd.read_excel('path')

# %%
diabitage_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabitage_df.shape
# Out:
# (768, 9)

# %%
#Exporting pandas dataframe as csv
california_df.to_csv('DataSets/california.csv')

#Similaryly we can do california_df.to_excel('path')

# %%
#creating dataframe of random valuas
randomDf = pd.DataFrame(np.random.rand(20,10))

# %%
randomDf.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.788164  0.211097  0.645163  0.543677  0.315743  0.613099  0.388397
# 1  0.638338  0.557254  0.034135  0.291180  0.024622  0.711064  0.043544
# 2  0.285026  0.407391  0.079747  0.992015  0.878264  0.730676  0.918697
# 3  0.395868  0.334164  0.607985  0.590008  0.400774  0.828248  0.824121
# 4  0.786645  0.218190  0.058399  0.019499  0.734382  0.707401  0.345192
#
#           7         8         9
# 0  0.180560  0.147930  0.816768
# 1  0.195165  0.174782  0.214414
# 2  0.598271  0.815889  0.410132
# 3  0.775256  0.315436  0.793166
# 4  0.712986  0.987534  0.305419

# %%
randomDf.shape
# Out:
# (20, 10)

# %% [markdown]
# Inspecting a dataframe

# %%
#finding a number of rows and columns
california_df.shape
# Out:
# (20640, 8)

# %%
#First 5 rows of DF
california_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
#Last 5 rows of DF
california_df.tail()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24

# %%
#Informations about DF
california_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB

# %%
#find the no of missing values 
california_df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
diabitage_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#Counting the values based on the levels
diabitage_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
#Group the values based on the mean
diabitage_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# Statistical measures

# %%
#Count or no of values
diabitage_df.count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
#Mean value columnbwise
diabitage_df.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
#Standard Deviation
diabitage_df.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
#Minimum value
diabitage_df.min()
# Out:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
#All the statistical measures about the dataset
diabitage_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Manupulating DF

# %%
#Adding column to dataframe
california_df['Price'] = california_dataset.target
california_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
#Removing a row
california_df = california_df.drop(index=0, axis=0)
california_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5  4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
#
#    Longitude  Price
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422
# 5    -122.25  2.697

# %%
#Removing a column
california_df.drop(columns='AveBedrms')
# Out:
#        MedInc  HouseAge  AveRooms  Population  AveOccup  Latitude  Longitude  \
# 1      8.3014      21.0  6.238137      2401.0  2.109842     37.86    -122.22
# 2      7.2574      52.0  8.288136       496.0  2.802260     37.85    -122.24
# 3      5.6431      52.0  5.817352       558.0  2.547945     37.85    -122.25
# 4      3.8462      52.0  6.281853       565.0  2.181467     37.85    -122.25
# 5      4.0368      52.0  4.761658       413.0  2.139896     37.85    -122.25
# ...       ...       ...       ...         ...       ...       ...        ...
# 20635  1.5603      25.0  5.045455       845.0  2.560606     39.48    -121.09
# 20636  2.5568      18.0  6.114035       356.0  3.122807     39.49    -121.21
# 20637  1.7000      17.0  5.205543      1007.0  2.325635     39.43    -121.22
# 20638  1.8672      18.0  5.329513       741.0  2.123209     39.43    -121.32
# 20639  2.3886      16.0  5.254717      1387.0  2.616981     39.37    -121.24
#
#        Price
# 1      3.585
# 2      3.521
# ...

# %%
#Locating a row using a index value
california_df.iloc[2]
# Out:
# MedInc          5.643100
# HouseAge       52.000000
# AveRooms        5.817352
# AveBedrms       1.073059
# Population    558.000000
# AveOccup        2.547945
# Latitude       37.850000
# Longitude    -122.250000
# Price           3.413000
# Name: 3, dtype: float64

# %%
#Locating a particular column
print(california_df.iloc[:,0]) #First column
print(california_df.iloc[:,1]) #Second ""
print(california_df.iloc[:,2]) #Third ""
print(california_df.iloc[:,-1]) #Last ""
# Out:
# 1        8.3014
# 2        7.2574
# 3        5.6431
# 4        3.8462
# 5        4.0368
#           ...
# 20635    1.5603
# 20636    2.5568
# 20637    1.7000
# 20638    1.8672
# 20639    2.3886
# Name: MedInc, Length: 20639, dtype: float64
# 1        21.0
# 2        52.0
# 3        52.0
# 4        52.0
# 5        52.0
#          ...
# 20635    25.0
# 20636    18.0
# 20637    17.0
# 20638    18.0
# 20639    16.0
# Name: HouseAge, Length: 20639, dtype: float64
# 1        6.238137
# 2        8.288136
# 3        5.817352
# 4        6.281853
# 5        4.761658
#            ...
# 20635    5.045455
# 20636    6.114035
# 20637    5.205543
# 20638    5.329513
# 20639    5.254717
# Name: AveRooms, Length: 20639, dtype: float64
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
# 5        2.697
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: Price, Length: 20639, dtype: float64

# %% [markdown]
# Correlation
# 1. Positive Correlation
# 2. Negative Correlation

# %%
california_df.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119164  0.326871  -0.062031    0.004946  0.018774
# HouseAge   -0.119164  1.000000 -0.153312  -0.077742   -0.296212  0.013194
# AveRooms    0.326871 -0.153312  1.000000   0.847635   -0.072186 -0.004851
# AveBedrms  -0.062031 -0.077742  0.847635   1.000000   -0.066206 -0.006182
# Population  0.004946 -0.296212 -0.072186  -0.066206    1.000000  0.069862
# AveOccup    0.018774  0.013194 -0.004851  -0.006182    0.069862  1.000000
# Latitude   -0.079941  0.011123  0.106361   0.069731   -0.108740  0.002369
# Longitude  -0.015028 -0.108141 -0.027501   0.013335    0.099717  0.002473
# Price       0.688000  0.105536  0.151902  -0.046690   -0.024552 -0.023735
#
#             Latitude  Longitude     Price
# MedInc     -0.079941  -0.015028  0.688000
# HouseAge    0.011123  -0.108141  0.105536
# AveRooms    0.106361  -0.027501  0.151902
# AveBedrms   0.069731   0.013335 -0.046690
# ...
